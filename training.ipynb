# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20332, done.
# remote: Counting objects: 100% (2446/2446), done.
# remote: Compressing objects: 100% (250/250), done.
# remote: Total 20332 (delta 2317), reused 2197 (delta 2196), pack-reused 17886 (from 1)
# Receiving objects: 100% (20332/20332), 11.14 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (14337/14337), done.

# %%
# %cd yolov10
# Out:
# /content/yolov10

# %%
# !pip install .
# Out:
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=731420 sha256=9573e3d5639066c2b158694783feb571703d796fbc44eef167a2d5cbce4f6b16
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tmrzfbsy/wheels/51/93/e8/22d2e815ced343915c15d86b2a00d95eb0a997d012527fbea7
# Successfully built ultralytics
# ...

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 26.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/yolov10/weights/yolov10n.pt
# Downloaded /content/yolov10/weights/yolov10s.pt
# Downloaded /content/yolov10/weights/yolov10m.pt
# Downloaded /content/yolov10/weights/yolov10b.pt
# Downloaded /content/yolov10/weights/yolov10x.pt

# %%
# !unzip license_data.zip
# Out:
# Archive:  license_data.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/0000_jpg.rf.68792df6709bb9eeda16387604141e29.jpg
#  extracting: test/images/0001_jpg.rf.41b947f79ad3a04fd04d9e1be627d4db.jpg
#  extracting: test/images/0009_jpg.rf.949aa145c7c07b717056182951ffd864.jpg
#  extracting: test/images/0018_jpg.rf.d6f9123cff1a9ad6ff69a1d213811041.jpg
#  extracting: test/images/0025_jpg.rf.dbd63f723945d104438d2ca25ea7ee98.jpg
#  extracting: test/images/0036_jpg.rf.2394c0f6b042af896ebce260daabb45f.jpg
#  extracting: test/images/0043_jpg.rf.7c966f70ca7a7c52325443a9a5ae0e8d.jpg
#  extracting: test/images/0060_jpg.rf.fef5b79c169bae85e5a9af07631af9ca.jpg
#  extracting: test/images/0061_jpg.rf.a2fa78f7242d5fffe67545212664ee23.jpg
#  extracting: test/images/0063_jpg.rf.4365b8d53783267aac6f016ad3fca069.jpg
# ...

# %%
# change the parameters according to the actual situation
# !yolo task=detect mode=train epochs=25 batch=2 plots=True model=weights/yolov10n.pt data=data.yaml
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
import os
from google.colab import files
zip_filename = "mytrain.zip"
shutil.make_archive(base_name=zip_filename.replace('.zip', ''),
                    format='zip',
                    root_dir='/content/yolov10/runs/detect/train')
print(f"Files have been zipped successfully to {zip_filename}")
files.download(zip_filename)
# Out:
# Files have been zipped successfully to mytrain.zip
